# %% [markdown]
# # Analysis of songs and their lyrics

# %% [markdown]
# ## Installation and loading of libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data and sources

# %% [markdown]
# ## Prints for Koppermaandag
# From the 18th century onwards, so called "Koppermaandagprenten" are retained in cultural heritage institutes. These prints are a proof of the quality of printing that a printshop was able to deliver. The labourers of a printshop made a print and brought them to the customers, expecting them to buy the print, or give a tip. This extra income was used to buy drinks on "Koppermaandag", a celebration on the first Monday after Epiphany.
#
# In 1991, an important publication is made about this type of printwork, with an overview of the retained Koppermaandagprenten. From this book the counts per year are available.

# %%
prentenDF = pd.read_csv("../data/koppermaandagprentenCount.csv", index_col="year")

print("Number of prints: "+ str(prentenDF['count'].sum()))
# Out:
# Number of prints: 554

# %% [markdown]
# ## Data about songs
# Between 1848 and ca. 1914 typographical associations created booklets with lyrics of songs they sang during feasts they organized. The dataset contains a table (in CSV) with an overview of all the songs in the booklets between 1848 and 1870, with among others title, year and writer.

# %%
liedjesDF = pd.read_csv("../data/liedjes.csv", dtype={'jaartal': 'Int32'})
liedjesDF = liedjesDF.sort_values(by=['songID'])

print("Number of songs:    " + str(len(liedjesDF)))
print("Number of booklets:  " + str(len(liedjesDF['sourceID'].unique())))
# Out:
# Number of songs:    771
# Number of booklets:  64

# %% [markdown]
# ## Song lyrics from files
# Besides the overview of the songs in a CSV-file, for every song there is a machine readable representation of the lyrics. We use the following functions to process them.

# %%
def getlistOfFilenames(rootdir):
    # input: rootdir: directory with (subdirectory with) TXT-files to be handled
	# output: list of TXT-files(+path) lexicographically ordered on path-name

    files_all = []
    for subdir, dirs, files in os.walk(rootdir):
        for file in files:
            if not file.endswith('.txt'):
                continue
            fn = os.path.join(subdir, file)
            files_all.append(fn)

    files_all = sorted(files_all)
    return files_all

def getlistOfTexts(listOfFilenames):
	# input: listOfFilenames: list of TXT-files(+path) lexicographically ordered on path-name
    # output: list of texts

	texts = []
	for file in listOfFilenames:
		with open(file) as stream:
			text = stream.read()
		texts.append(text)

	return texts

# %% [markdown]
# We use the above functions to read the lyrics.

# %%
liedjesFilenames    = getlistOfFilenames('../data/lyrics')
liedjes             = getlistOfTexts(liedjesFilenames)

# %% [markdown]
# To investigate whether our code has worked, we look at the data of song with number ```n```.

# %%
n = 100

print("-- data: --")
print(liedjesDF.iloc[n])
print("-- path: --")
print(liedjesFilenames[n])
print("-- song: --")
print(liedjes[n])
# Out:
# -- data: --
# typoID                                                      amsterdam1849
# sourceID                                  amsterdam1849-feestliederen1862
# songID                                 amsterdam1849-feestliederen1862-06
# titel                   De boekdrukkunst beschouwd als het licht der v...
# wijze                                   Makkers brengt met stem en snaren
# jaartal                                                              1862
# schrijver                                                        H. Stühr
# vereniging_schrijver                                        amsterdam1849
# Name: 164, dtype: object
# -- path: --
# data/lyrics/amsterdam1849/amsterdam1849-feestliederen1862/amsterdam1849-feestliederen1862-06.txt
# -- song: --
# De boekdrukkunst
#
# Is de zaal thans weêr ontsloten,
# Voor het jaarlijks Kopperfeest,
# Laat ons dan dit feest vergrooten,
# Met een regt verheugden geest;
# Voegt u hier dan, Typographen !
# Door geen bange zorg gedrukt,
# Dat gij Costers roem blijft staven,
# Nu ge in vreugd hier lauwren plukt.
#
# Mogt een kunst zich fier verheffen,
# Bij de Drukkunst haalt zij miet,
# Dankbaar zal dit elk beseffen,
# Daar haar werking eeuwen ziet;
# Vorst en volk zijn door haar luister,
# Aan het helderst licht gebragt,
# Zelfs die dwalen, in het duister,
# Schenkt zij licht in menig nacht.
#
# Jaar op jaar zien wij haar vruchten,
# Uitgedeeld aan 't verste strand
# Ook die slaafsche boei doen zuchten,
# Zìen haar heilbanier geplant.
# O! nog millioenentallen,
# Zien nog eens haar glansrijk licht,
# Hoe gal dan de juichtoon schallen,
# Als het duister voor haar zwicht.
#
# Zoudt gij u dan niet verblijden,
# Gij, die in haar werkkring woelt ?
# Zoudt ge aan haar geen danktoon wijden,
# Daar uw werk elks heil bedoelt?
# Op dan, Makkers! Kunstgenooten !
# De eer aan Boekdrukkunst gebragt ;
# Laten wij haar roem vergrooten,
# Als een dankbaar nageslacht.

# %% [markdown]
# # Stanza size

# %%
n = 0
vondst = False
for liedje in liedjes:
    liedje_regels = liedje.split('\n')
    i = 0
    for line in liedje_regels:
        if line == '':
            if i > 1 and i < 7: vondst = True
            i = 0
        else: i = i + 1
    if vondst:
        print("-- data: --")
        print(liedjesDF.iloc[n])
        print("-- song: --")
        print(liedje)
    n = n + 1
    vondst = False
# Out:
# -- data: --
# typoID                                   amsterdam1847
# sourceID                   amsterdam1847-reglement1848
# songID                  amsterdam1847-reglement1848-02
# titel                                              NaN
# wijze                                              NaN
# jaartal                                           1848
# schrijver                                          NaN
# vereniging_schrijver                     amsterdam1847
# Name: 65, dtype: object
# -- song: --
# - II
# Komt, vriende in het rond,
# Zingt met een blijden mond
# Ter eer van Laurens Koster.
# Wij zijn hier bij elkaar,
# Een regte vriendenschaar
# Om zijnen roem te melden.
#
# Ja Koster, kunstgenoot
# Wij zullen tot den dood
# U vond aan elk veronden:
# Gij gaf ons het bestaan
# Geen Duitscher heeft ‘t gedaan
# Wij zijn aan u verbonden.
#
# Daarom, o vriendenkring
# Laat ons dan onderling
# Met vreugde hem gedenken
# En blijven hem gehecht
# Het pleit is lang beslecht
# Dat Koster vond de Drukkunst
#
#
# -- data: --
# typoID                                   amsterdam1847
# sourceID                   amsterdam1847-reglement1848
# songID                  amsterdam1847-reglement1848-09
# titel                                              NaN
# wijze                                         Io Vivat
# jaartal                                           1848
# schrijver                                          NaN
# vereniging_schrijver                     amsterdam1847
# Name: 72, dtype: object
# -- song: --
# - IX
#
# ‘t Is vreugde feest, ‘t is vreugde feest,
# Heft aan een vrolijk lied,
# De langgewenschte dag is daar,
# Zoo blij voor onze Vriendenschaar;
# ‘t Is vreugde feest, ‘t is vreugde feest,
# Smoort thans uw zangen niet.
#
# ‘t Is vreugde feest, ‘t is vreugde feest,
# Voor Kosters Vriendenkring.
# De vriendschap die ons heeft vereend,
# Heeft ons het rijkst genot verleend;
# ‘t Is vreugde feest, ‘t is vreugde feest,
# Voor Kosters Vriendenkring.
#
# ‘t Is vreugde feest, ‘t is vreugde feest,
# Zingt allen zonder dwang.
# De vriendschap die deez’ feestdag siert,
# Wordt door een vrolijk lied gevierd;
# ‘t Is vreugde feest, ‘t is vreugde feest,
# De vriendschap mint de zang.
#
#
# -- data: --
# typoID                                    amsterdam1847
# sourceID                    amsterdam1847-reglement1848
# songID                   amsterdam1847-reglement1848-10
# titel                                               NaN
# wijze                   Ik ben een Nederlandsch Soldaat
# jaartal                                            1848
# schrijver                                           NaN
# vereniging_schrijver                      amsterdam1847
# Name: 73, dtype: object
# -- song: --
# - [X]
# Wijze: Ik ben een Nederl. soldaat
#
# Wie ‘s levensvreugd ontvlied en haar
# Steeds zorg in’t oog doet lezen.
# Altijd het strak en stroef gelaat
# In de eigen norschen rimpel staat,
# Diens vriend wil ik niet wezen.
#
# Ik haat het koud en stug gemoed
# Dat nadenkt bij zijn vrinden.
# Waarachtig ‘t staat bij hem niet goed,
# Die altijd nadenkt wat hij doet,
# Waar hij zich moog’ bevinden.
#
# Maar hij die zorgen en gewin,
# Aan tfel kan verbannen.
# Die dart’len kan met kinderzin,
# Heeft zeker deugd en onschuld in,
# Diens geest weet zich te ontspannen.
#
# ‘k Zwier, Kosters Vriendenkring ter eer
# Met blijgestemde zinnen;
# Den vollen beker heen en weer,
# En stuur dien, trouw aan mijne leer,
# In eene teug naar binnen.
#
#
# -- data: --
# typoID                                   amsterdam1847
# sourceID                   amsterdam1847-reglement1848
# songID                  amsterdam1847-reglement1848-11
# titel                                              NaN
# wijze                        O groote koopman in tabak
# jaartal                                           1848
# schrijver                                          NaN
# vereniging_schrijver                     amsterdam1847
# Name: 74, dtype: object
# -- song: --
# - [XI]
# Wijze: O groote koopman in tabak
#
# Doet alles matig is de les,
# Die grootpapa Hippocrates
# In ‘t grieksch ons heeft gegeven.
# Die matig drinkt en matig eet,
# Kan zonder ziekte, pijn of leed
# Wel honderd jaren leven.
#
# Van tijd tot tijd een goed glas wijn
# Zal niemand ooit tot schade zijn,
# Maar doet de kracht bewaren.eeft moed en lust om goed te doen,
# Dan haalt men duizend jaren.
#
# Die dus tien eeuwen leven wil,
# Die wandelt immer vroom en stil,
# Als op fluwele schoentjes
# En smake in alle eer en deugd,
# Bij matigheid ‘t genot der vreugd
# Aan roode wijn met zoentjes
#
# -- data: --
# typoID                                   amsterdam1847
# sourceID                   amsterdam1847-reglement1848
# songID                  amsterdam1847-reglement1848-12
# titel                                              NaN
# wijze                                         Io Vivat
# jaartal                                           1848
# schrijver                                          NaN
# vereniging_schrijver                     amsterdam1847
# Name: 75, dtype: object
# -- song: --
# - [XII]
# Io vivat, io vivat,
# Komt broeders plengt den wijn,
# De beker waar het vocht in spat,
# Nu lustg zingend aangevat,
# Io vivat Io vivat,
# Er moet geklonken zijn.
#
# ‘t Io vivat, ‘t Io vivat,
# Klinkt door deez’ ruime zaal,
# De vijftienjaarge porterwijn,
# Moet thans voor Kosters Vrienden zijn,
# Io vivat, Io vivat,
# Geleegd zij de bokaal
#
# Io vivat, Io vivat,
# Dat stort ons kracht in ‘t bloed,
# Herhaald dien drink tot Koster’s eer,
# En meld zijn’ vining keer op keer,
# Io vivat, Io vivat,
# Deez’ porterwijn smaakt goed.
#
# -- data: --
# typoID                                            amsterdam1849
# sourceID                          amsterdam1849-feestbundel1851
# songID                         amsterdam1849-feestbundel1851-01
# titel                                           De dankbaarheid
# wijze                   Wie praalt aan 't hoofd der Heldenstoet
# jaartal                                                    1851
# schrijver                                                   NaN
# vereniging_schrijver                              amsterdam1849
# Name: 77, dtype: object
# -- song: --
# De dankbaarheid
#
# Kent gij de schoonste deugd op aard? Gewis!
# Een deugd, ons aller hulde waard? Gewis!
# O ja, gij kent haar, vriendenrij!
# Gij toont het op dit feestgetij!
# Gewis ! gewis! gewis!
#
# Kent gij een deugd zoo groot, zoo schoon? O ja!
# Steeds waardig eene lauwerkroon? O ja!
# Gewis, gij zingt dit uit den geest,
# Gij toont het op dit vriendenfeest!
# O ja! o ja! o ja!
#
# Kent gij den aller deugden roem? Gewis!
# Ook zonder dat ik u hem noem! Gewis!
# Ja, u bezielt dit deugdenvuur,
# Gij allen toont het in dit uur!
# Gewis , gewis! gewis!
#
# Heil, REGENBOOG ! heil, LAMSVELDT ! heil! O ja!
# Ook HESSEL zegen zonder peil! O ja!
# Heil, STOM! ja, heil u altemaal,
# Uw borst siert thans het eermetaal!
# Heil , driewerf heil, o ja!
# -- data: --
# typoID                                             amsterdam1849
# sourceID                           amsterdam1849-feestbundel1851
# songID                          amsterdam1849-feestbundel1851-02
# titel                                             De vriendschap
# wijze                   Hoe zoet is ‘t waar de vriendschap woont
# jaartal                                                     1851
# schrijver                                                    NaN
# vereniging_schrijver                               amsterdam1849
# Name: 78, dtype: object
# -- song: --
# De vriendschap
#
# Hoe zoet is 't waar de vriendschap woont,
# Zij is opregt van aard ;
# Zij wordt met myrth en palm gekroond,
# Haar glans is prijzenswaard.
# Zij zet ons zaâm tot vreugde aan,
# Wie wil haar’ invloed wederstaan ?
# Geen mensch! geen mensch! geen mensch!
#
# De vriendschap brengt ons in één zin,
# Zij zet geen stuursch gelaat;
# Zij is een zusje van de min,
# Ook schuwt ze twist en haat.
# De Medailles zijn dan uit dien geest,
# En we juichen vrolijk op dit Feest,
# Met zang! met zang! met zang!
#
# O Vriendschap en gezelligheid!
# Men vindt u nooit alleen;
# Gij zelv' hebt deze eer bereid,
# Gij bragt ons hier bijeen,
# Elk roep’ dan vrij tot leniging:
# Heil, heil zij deez’ Vereeniging!
# O ja! o ja! o ja!
#
# Elk neem’ zijn glaasje in de hand,
# En bied’ zijn vriendschap aan;
# Fey schenke ’t vol tot aan den rand,
# ‘t Kan er nu wel op staan.
# Wij drinken ’t dan met blijdschap uit,
# Dat niets de gulle vriendschap stuit’!
#
# Geen stond! geen stond! geen stond!
#
# -- data: --
# typoID                                     amsterdam1849
# sourceID                   amsterdam1849-feestbundel1851
# songID                  amsterdam1849-feestbundel1851-05
# titel                                       De Medailles
# wijze                             Marchand de parapluies
# jaartal                                             1851
# schrijver                                            NaN
# vereniging_schrijver                       amsterdam1849
# Name: 81, dtype: object
# -- song: --
# De Medialles
#
# Al is uw Medaille geen eerkruis of ster
# Toch staat zij u deftig en blinkt reeds van ver’
# Blijft, Vrienden ! haar dragen
# Nog jaren en dagen;
# Gij hebt haar op 't glansrijkst verdiend !
# Zij spoor’ u steeds aan,
# Om voorwaarts te gaan ,
# En moog’ ons nog naauwer verbroedren ;
# Uw ijver en vlijt
# Blijft nu en altijd
# Aan 't heil van ons allen gewijd.
#
# Heeft Vriendschap dit uur er uw borst meê versierd,
# Op 't vrolijke feest u op nieuw hier gevierd;
# O doe ons nog jaren
# Hier vreugde vergaren ,
# GENOEGEN EN VOORZORG zij 't doel.
# Dat heerschzucht noch dwang
# De vriendschap vervang'
# Die Gij ons voortdurend wilt schenken ;
# Vervul uw bestuur
# Met lust en met vuur,
# Dan bloeit deze Kring op den duur.
#
# VROUWEN:
# Maar, Heeren Bestuurdren! wij hebben een vraag
# Wij zijn wat nieuwsgierig en kijken eens graag
# Laat dus nu de vrouwen
# Eens digtbij beschouwen
# Wat Vriendschap in dit uur u bood
# Schenkt ons dat plezier
# Komt eventjes hier,
# Laat ras uw Medailles eens kijken ;
# Wat blinken ze schoon !. ..:
# Hij die ze vertoon,
# Ontvangt hier een kus tot zijn loon.
#
# MANNEN:
# Wel Vrouwtjes! wel Vrouwtjes! heet dat nu fatsoen ?
# Medailles te kijken, en dat voor een zoen!
# Doch . . . . ga vrij uw gang maar,
# En houdt thans uw wang klaar ,
# Zij hebben ’t ook dubbel verdiend.
#
# TE ZAMEN.
# Ja, lof zij ‘t Bestuur
# Gebragt in dit uur,
# Bij kussen en drinken en zingen.
# Hun voorzorg en vlijt,
# Die ’t hart ons verblijdt ,
# Zij nogmaals een danktoon gewijd !
#
#
# -- data: --
# typoID                                            amsterdam1849
# sourceID                        amsterdam1849-feestliederen1852
# songID                       amsterdam1849-feestliederen1852-07
# titel                                              Kosters Roem
# wijze                   Wie praalt aan 't hoofd der Heldenstoet
# jaartal                                                    1852
# schrijver                                           S.T. Deinum
# vereniging_schrijver                              amsterdam1849
# Name: 89, dtype: object
# -- song: --
# Kosters roem
#
# Waar zag de grootste kunst het licht, o waar?
# Een kunst, waar alle kunst voor zwicht, o waar?
# In Nederland, alom vermaard,
# Ontstond dit groot geschenk voor daard’!
# Hoezee! hoezee! hoezee!
#
# Wie was de Stichter van die kunst, ja, wie?
# Wie schonk het aardrijk zulk een gunst, ja, wie?
# De man, die ons dien zegen gaf,
# Ligt ruim vier honderd jaar in ’t graf!
# Zoo lang! zoo lang! zoo lang!
#
# Zijn naam leeft echter nog in ’t rond, ei? ei?
# Deez’ dag ging hij van mond tot mond, ei? ei?
# Ja, dezen dag vlecht men een kroon,
# Aan Hollands eed'len Kunstenzoon!
# Bravo! bravo! bravo!
#
# Deez’ dag verkondigt luid de Faam, in ’t rond,
# Een voor Oud-Neêrland dierbren naam, met grond;
# Die naam leeft nog in volle kracht,
# En duurt tot bij het nageslacht!
# Gewis! gewis! gewis!
#
# Thans staat gij, KOSTER! nog in steen, o ja!
# Doch spoedig komt men op de been, weldra!
# Och, dat men nu niet lang meer draal’,
# Om U te plaatsen in metaal!
# Tot vreugd! tot vreugd! tot vreugd!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1852
# songID                  amsterdam1849-feestliederen1852-11
# titel                                         Feestvreugde
# wijze                          De wereld is in rep en roer
# jaartal                                               1852
# schrijver                                     J. Sondervan
# vereniging_schrijver                         amsterdam1849
# Name: 93, dtype: object
# -- song: --
# Feestvreugde
#
# 't Is vreugde in deez’ ruime zaal,
# Bij gullen zang en warme taal!
# Bij vrolijk feesttijvieren !
# Hoezee! het is weêr Kopperdag,
# Waarop de geest zich spannen mag,
# Om Kosrer's naam te sieren!
#
# Wie thans niet juicht met blijden geest,
# Behoort niet op dit vriendenfeest ;
# Had hij te huis gebleven,
# Dan had hij zeker goed gedaan,
# Want nu zal hij verwonderd staan,
# Hoe vrolijk wij hier leven.
#
# Hier juicht men allen eensgezind,
# Want hij die twist of onmin mint,
# Zal spoedig zich vervelen.
# Terwijl de Haak en Drukpers rust,
# Wordt hier gedanst, gekout, gekust:
# Wien zou dit Feest niet streelen.
#
# Hoezee! de Kopperfeestpartij,
# Wordt weêr gevierd verheugd en blij!
# Het voegt ons thans te danken
# Het waard Bestuur, dat vol van vuur,
# Gezorgd heeft voor dit vrolijk uur,
# Met warme vriendschapsklanken!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1852
# songID                  amsterdam1849-feestliederen1852-13
# titel                   Lied op het vereeren der medailles
# wijze                               Marchand de parapluies
# jaartal                                               1852
# schrijver                                       J. Buhling
# vereniging_schrijver                         amsterdam1849
# Name: 95, dtype: object
# -- song: --
# Lied op het vereeren der medailles
#
# Al is de Medaille geen eerkruis of ster,
# Toch staat zij steeds deftig en blinkt reeds van verr’.
# Blijft, Vrienden! haar dragen
# Nog jaren en dagen ;
# Gij hebt haar op ‘t glansrijkst verdiend!
# Zij spoor’ U steeds aan,
# Om voorwaarts te gaan,
# En moog’ ons nog naauwer verbroedren;
# Uw ijver en vlijt
# Blijft nu en altijd
# Aan ‘t heil van ons allen gewijd.
#
# Heeft Vriendschap er thans uwe borst meê versierd,
# Op ’t Kopperfeest hier op nieuw weêr gevierd;
# O doet ons nog jaren
# Hier vreugde vergâren,
# GENOEGEN en Voorzorg zij ’t doel.
# Dat heerschzucht noch dwang
# De vriendschap vervang,
# Die Gij ons voortdurend wilt schenken;
# Vervult uw bestuur
# Met lust en met vuur,
# De bloeit deze Kring op den duur.
#
# DAMES:
# Maar, Heeren Bestuurdren! wij hebben een vraag -
# Wij zijn wat nieuwsgierig, en kijken eens graag
# Laat dus nu de Vrouwen
# Met vreugde beschouwen
# Wat Vriendschap men U heeft betoond.
# Schenkt ons dat plezier,
# Zijt er trotsch op en fier,
# Laat ras uw Medailles maar kijken;
# Wat blinken ze schoon!
# Hij, die ze vertoon,
# Ontvangt hier een kus tot zijn loon
#
# HEEREN:
# Wel Vrouwtjes! wel Vrouwtjes! heet dat nu fatsoen?
# Medailles te kijken, en dat voor een zoen!
# Maar... gaat vrij uw gang maar,
# En houdt thans uw wang klaar,
# Zij hebben ’t ook dubbel verdiend.
#
# TE ZAMEN:
# Ja, lof zij ’t Bestuur
# Gebragt in dit uur,
# Bij kussen en drinken en zingen.
# Hun voorzorg en vlijt,
# Die ’t hart ons verblijdt,
# Zij nogmaals een danktoon gewijd!
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1852
# songID                  amsterdam1849-feestliederen1852-16
# titel                              Vriendschap en eendragt
# wijze                    Triomf! De vreugde stijgt ten top
# jaartal                                               1852
# schrijver                            F. Gerrebrand Croesen
# vereniging_schrijver                         amsterdam1849
# Name: 98, dtype: object
# -- song: --
# Vriendschap en eendragt
#
# Triomf! zoo klinkt ons feestlijk lied !
# Nu deze dag ons vreugde biedt,
# Rijst uit het hart en mond de opgeruimdste toon,
# Daar ons, te zamen hier vergaârd,
# De Vriendschap weêr genoegen baart,
# O deugd, zoo heerlijk schoon!
#
# Triomf! zoo juicht een elk verblijd;
# 't Genoegen ons hier voorbereid,
# Wordt nu gesmaakt in onzen grooten vriendschapskring,
# Hier ziet de vriendschap zich gekroond;
# Hier wordt zij niet in ’t minst gehoond,
# Zij vormt vereeniging!
#
# Vereeniging! als door een band,
# Gevoelen wij ons naauw verwant,
# Die nu door ‘t zoetst genot te meer wordt toegehaald,
# Terwijl uit aller oog en hart,
# Geen kommer, leed, of druk, of smart,
# Maar vrolijkheid slechts straalt.
#
# O Vrienden! sluiten wij ons zaam,
# Tot roem en eer van Koster’s naam,
# Wiens eedle kunst ook hier zoo heerlijk wordt herdacht,
# Genoegen blijve dan bestaan;
# Zoo min als Voorzorg moog’ 't vergaan
# Voor ’t volgende geslacht!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1852
# songID                  amsterdam1849-feestliederen1852-18
# titel                           Hulde aan de boekdrukkunst
# wijze                    Daar komt de kiel met goud belaan
# jaartal                                               1852
# schrijver                                      J.C. Kröber
# vereniging_schrijver                         amsterdam1849
# Name: 100, dtype: object
# -- song: --
# Hulde aan de boekdrukkunst
#
# Komt, vrienden! juicht thans blij van geest,
# Hier op ons Koppermaandag-feest !
# Komt, heft den zangtoon aan en juicht als wij hier meê,
# Komt, vlechten wij tot eer en glans,
# Der Boekdrukkunst een lauwerkrans,
# En juichen wij hoezee!
#
# Ja, Drukkunst! u zij eeuwig prijs,
# Van ‘t nut erlangen wij ’t bewijs,
# Gij brengt ons voordeel aan tot nut van ’t algemeen,
# Dus U zij dan deez’ zang gewijd,
# Op 't feest dat aller hart verblijdt,
# Genoegen schenkt meteen.
#
# Gij waart de grondsteen van deez’ band,
# Geleid door 's Allerhoogsten hand,
# Wat men hier in deez’ kring Genoegen, Voorzorg noemt
# O Ja, gij draagt daartoe steeds bij,
# De stichting dezer Maatschappij
# Dit is t waar men U om roemt.
#
# Ja zonder U was nooit deez’ kring
# Tot stand gebragt, zoo onderling ;
# Het menschdom was gekneld in duister onverstand ;
# Maar thans geeft gij Uw licht, voorwaar,
# Voor ’t menschlijk heil in ’t openbaar,
# Gezegend door Gods hand.
#
# Dus Kosrer dan zij lof en dank
# Door ons gebragt in vreugdeklank ;
# Hij stelde door zijn hand die ed’le kunst ten toon,
# Door ons híer allen zoo vereerd,
# Als 't heil dat men op 't hoogst waardeert:
# Her zij Hem dus tot loon!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1852
# songID                  amsterdam1849-feestliederen1852-19
# titel                                    Het drukkersleven
# wijze                    Es kann ja nicht immer so bleiben
# jaartal                                               1852
# schrijver                                   J. Schaftenaar
# vereniging_schrijver                         amsterdam1849
# Name: 101, dtype: object
# -- song: --
# Het drukkersleven
#
# Wij wakk're Drukkersgezellen,
# Wij leven bij arbeid en lied,
# Hoe and'ren om ’t leven zich bedien
# Wij leven — maar zonder verdriet.
#
# Bij d’ aanblik van iederen morgen,
# Is Drukker en Zetter steeds Klaar;
# De arbeid baart nimmer ons zorgen,
# Al valt hĳj ook dikwijls wat zwaar.
#
# Behoefte is groot, doch tevreden
# Snelt 't leven zoo zachtkens voorbij ;
# De zon moog’ in wolken zich kleeden,
# Ons treft slechts de smart van ter zij!
#
# Verlichting en kennis te schragen,
# Is ’s Drukkers beroep en vermaak;
# Het licht des verstands te doen dagen,
# Ons doel, onze vreugd, onze zaak!
#
# Komt, zonen van Koster! weest blijde,
# Zoo toont ons het leven op aard’
# Hier altijd zijn bloemrijke zijde,
# Zoo zijn wij voor doornen bewaard!
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1852
# songID                  amsterdam1849-feestliederen1852-20
# titel                                          Herinnering
# wijze                       Wij leven vrij, wij leven blij
# jaartal                                               1852
# schrijver                                       J. Koek Jz
# vereniging_schrijver                         amsterdam1849
# Name: 102, dtype: object
# -- song: --
# Herinnering
#
# Wat schoon verschiet blinkt voor ons oog
# Bij ’t bloeijen van deez’ kring,
# Wat ooit in asch of damp vervloog,
# Wat tijd of ramp op aard’ vermoog’,
# De kunst verhef zich meer omhoog,
# Dat elk haar lof bezing’.
#
# Dat lang gewenschte uur brak aan,
# Waarop wij vieren feest ;
# Heeft het tweede ons reeds goed voldaan
# Het derde lacht ons vriendelijk aan ;
# Deez' dag zal hopen w’ nooit vergaan
# Van Kosters vindingsgeest.
#
# Welaan vermaken wij ons thans,
# Vooral geen tijd verzaakt
# Het is nu tijd van zang en dans.
# Wij vinden hier een nieuwen glans,
# Want feest te vieren zoo als thans,
# Voorwaar, dat is volmaakt!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1857
# songID                  amsterdam1849-feestliederen1857-01
# titel                                            Jubelzang
# wijze                                     De scheepsjongen
# jaartal                                               1857
# schrijver                                     C. Regenboog
# vereniging_schrijver                         amsterdam1849
# Name: 105, dtype: object
# -- song: --
# Jubelzang
#
# Aangeheven, feestgenoten!
# Op het blijde Kopperfeest,
# Laat uw lied de vreugd vergrooten, 't is uwe taak!
# Jubel met een' blijden geest, 't is uwe taak!
# Tot de eer der zaak.
#
# Heft aan het lied in blijde koren,
# Roemt onze leus, roemt (heden) haar bestaan;
# Laat opgeruimd iw zangstem hooren,
# Zij moge vrolijk opwaarts gaan.
# Men mag met regt deez' feestdag vieren,
# Verheffen onze schoone Kring;
# Haar met een lauwerkrans versieren,
# Om 't schoon, wat men in haar ontving.
#
# Het achtste jaar is nu verdwenen,
# Het volgend vangt zijn werkkring (heden) aan;
# Wat schoon is in dien tijd verschenen,
# Wat onspoed zijn wij niet ontgaan.
# Daarom de feesttoon aangeheven,
# Genoegen viert het Kopperfeest,
# En alom heerscht er kracht en leven
# Bij 't Ledental de eendragtsgeest.
#
# Bestuurdren! vlecht met uwe Leden
# Op nieuwe dit jaar de (schoone) eendragtsband,
# Dan wordt de goede weg betreden,
# Dan biedt ge in nood elkaar de hand;
# Dan zal de spreuk der Kring floreeren,
# Gelijk ze nu tot heden deed;
# Dan zal de roem der zaak vermeeren,
# Door dat ge uw zorgn aan haar besteed.
# -- data: --
# typoID                                        amsterdam1849
# sourceID                    amsterdam1849-feestliederen1857
# songID                   amsterdam1849-feestliederen1857-06
# titel                               Herinnering aan Haarlem
# wijze                   Hebt gij ooit Haarlems stad bezocht
# jaartal                                                1857
# schrijver                                        J. Buhling
# vereniging_schrijver                          amsterdam1849
# Name: 110, dtype: object
# -- song: --
# Herinnering aan Haarlem
#
# Allen
# Wat zitten wij hier blij van geest,
# Geen zorgen doen ons schromen;
#
# Vrouwen
# 't Gaat beter dan op 't Haarlems feest,
# Daar mogten wij niet komen;
# Gij at er elk een pop,
# Met nog twee kwartjes op,
# En zat er braaf te smullen,
# Terwijl wij onze maag, dien dag,
# Met kliekjes konden vullen;
# 't Gaf reden tot beklag.
#
# Mannen
# Helaas! wat hebben wij gehad?
#
# Vrouwen
# Vast meer toch dan wij vrouwen;
#
# Mannen
# Dien maaltijd in de Kenaustad,
# Zal elk van ons onthouen;
# Want hoort de zaak in 't kort:
# Duinwatersoep - een bord -
# Wij willen het wel weten -
# Drie aardappels een bloemkoolstruik,
# Was dat geen heerlijk eten?
# Maar 't schijnt daar zoo 't gebruik.
#
# Vrouwen
# Och, kom! dat maakt gij ons niet wijs!
#
# Mannen
# Ga 't aan Bestuurd'ren vragen;
#
# Vrouwen
# Dat 's magre kost voor hoogen prijs,
#
# Mannen
# Wij hadden reen tot klagen;
# Maar zgt, hebt gij in stad,
# Hier ook vermaak gehad?
#
# Vrouwen
# Ja zeker, toen gij zamen,
# De Beurs afkwaamt, met uw Banier,
# Toen wij daar kijken kwamen,
# Had elk van ons pleizier.
#
# Allen
# Daarom ook willen wij
# Hen opgeruimd en blij,
# Gedachtig zijn,
# Wier gunst - eer 't feestuur klonk -
# Ons die Banier hier schonk,
# En wijden hun een dronk
# Met dit glas wijn!
# -- data: --
# typoID                                            amsterdam1849
# sourceID                        amsterdam1849-feestliederen1857
# songID                       amsterdam1849-feestliederen1857-09
# titel                                 Eigen haard is goud waard
# wijze                   Wie praalt aan 't hoofd der Heldenstoet
# jaartal                                                    1857
# schrijver                                           J.C. Kröber
# vereniging_schrijver                              amsterdam1849
# Name: 113, dtype: object
# -- song: --
# Eigen haard is goud waard
#
# Mannen
# Toen men laatst Haarlems vest bezocht, spreek op!
# Werdt toen de vreugd niet duur gekocht, spreek op!
# Was t' op het Haarlemsche festoen,
# Om u of om uw geld te doen,
# Spreek op! spreek op! spreek op!
#
# Gij, die Apollo's zaal bezoekt, hoezee!
# Leest wat er van haar staat geboekt, hoezee!
# Het schoon van aardsche zaligheid,
# Werdt ons in deze zaal bereidt;
# Hoezee! hoezee! hoezee!
#
# Vrouwen
# Ja hier, hier stemmen wij mee in, 't is waar!
# Die reis gaf u een slecht gewin, 't is waar!
# Bij al het heil, wat gij genoot,
# Was 't of een vrouw er overschoot;
# 't Is waar! 't is waar! 't is waar!
#
# Mannen
# Nu, Vrouwtjes! weest nu maar tevreen, hoezee!
# Smaakt thans weer vreugd gelijk voorheen, hoezee!
# Komt vieren wij weer met elkaar,
# Dit feest, gelijk het vorig jaar;
# Hoezee! hoezee! hoezee!
#
# Allen
# Komt, zingen wij dan op dit feest, hoezee!
# Steeds vrolijk opgeruimd van geest, hoezee!
# En juichen wij hier zaam vergaard,
# Geen beter plek als eigen haard!
# Hoezee! hoezee! hoezee!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1857
# songID                  amsterdam1849-feestliederen1857-10
# titel                       Zonder vrouwtjes geen plaisier
# wijze                          De wereld is in rep en roer
# jaartal                                               1857
# schrijver                                        A. Kreyts
# vereniging_schrijver                         amsterdam1849
# Name: 114, dtype: object
# -- song: --
# Zonder vrouwtjes geen plaisier
#
# Zonder Vrouwtjes geen plaisier,
# Zonder Meisjes geen vertier,
# Ja zelfs geen genoegen.
# Wat was een Kopperfeestpartij,
# Had men geen Vrouwtje aan zijn zij,
# Wij zouden ons bedroeven.
#
# Men viert geen vrolijk kopperfeest
# Was er geen Eva bij geweest,
# Wat zou het ons berouwen.
# O nee! wij hadden geen vermaak,
# Want vreugde vindt men al te vaak
# Door Meisjes en door Vrouwen.
#
# Waar Vrouwtjes zijn kan het geen kwaad,
# Van 't feest zijn zij 't schoonst sieraad,
# En zij bewaren vrede.
# Daarom nu wij dan van ons huis,
# Marcheerden naar de Hoogesluis,
# Nu moesten zij ook mede.
#
# Wij juichen U dan 't welkom toe,
# Weest welkom alle, blij te moe,
# Ja, welkom lieve Vrouwen!
# Triomf! wij vieren weer ons feest
# Met U vereend, verheugd van geest,
# Dat zal ons niet berouwen.
#
# Hoezee dan 't feest waar Vrouwen zijn,
# Want zonder hen, en zonder wijn,
# Zou 't weinig vreugde geven.
# Want ach, men hoort somtijds van twist,
# Waar men de lieve Vrouwen mist,
# Is 't niet genoeg'lijk leven.
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1857
# songID                  amsterdam1849-feestliederen1857-13
# titel                                 Opwekking tot dansen
# wijze                            Schep vreugde in 't leven
# jaartal                                               1857
# schrijver                                    J.M. van Gool
# vereniging_schrijver                         amsterdam1849
# Name: 117, dtype: object
# -- song: --
# Opwekking tot dansen
#
# Komt aan het dansen,
# Allen vrolijk in het rond;
# Komt aan het dansen,
# Vlug van den grond.
#
# Nu, Vrienden! lustig opgestaan,
# En nu eens aan den dans gegaan,
# Want al dat zitten, weet ge wek,
# Dat geeft maar stijve beenen.
#
# 't Orkest is reeds in volle gang,
# De dans verwissele de zang,
# Zoo houdt men lijf en ziel gezond,
# En vlugheid in de beenen.
#
# Bestuurderen ga ons vooruit,
# We noodigen u allen uit,
# Ons in het dansen voor te gaan,
# Wij zullen u dan volgen.
#
# Een ieder danst met vreugd en lust,
# Want, Vrienden! niet te lang gerust,
# En na veel dansen kunnen wij
# Deez' nacht toch beter rusten.
#
# En is de danslust dan voldaan,
# En moeten wij naar huis toe gaan,
# Dan hopen wij het volgend jaar,
# Op nieuw weer te beginnen.
#
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1857
# songID                  amsterdam1849-feestliederen1857-14
# titel                                            Feestzang
# wijze                                         Trien, Trien
# jaartal                                               1857
# schrijver                                         H.A. Mak
# vereniging_schrijver                         amsterdam1849
# Name: 118, dtype: object
# -- song: --
# Feestzang
#
# O welk een vreugd een Koppperfeest te vieren,
# Wie doet zoo iets niet gaarne ieder jaar?
# En als de vriendschap dan het Feest mag sieren,
# Dan doet men gaarne alles voor elkaar,
# Ja, ja, ieder doet
# Wat de vreugd verhoogen moet.
#
# Komt dan een blij, vrolijk lied gezongen,
# En eens een klas aan ;t Koppergesst gewijdt,
# Dat sterkt de vreugd en smeert de stroeve longen,
# En geeft het Feest en kracht en moed en vlijt,
# Ja, ja, zang en wijn,
# Doen een Feest eerst vrolijk zijn.
#
# Komt, vrienden! dan, wij wenschen u met dezen,
# Dat weer dit jaar als het verleden zij,
# Laat heil en vreugd uw trouw gezelschap wezen,
# Danleven wij steeds vergenoegd en blij;
# Ja, ja, heil en vreugd,
# Maakt de ouderdom tot jeugd.
#
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1858
# songID                  amsterdam1849-feestliederen1858-01
# titel                             Typographische feestzang
# wijze                   Eens werd er aan de zeeuwsche kust
# jaartal                                               1858
# schrijver                                     A. Hogenhuis
# vereniging_schrijver                         amsterdam1849
# Name: 121, dtype: object
# -- song: --
# Typographische feestzang toegzongen aan heeren patroons en donateuren.
#
# MANNEN-
# Hoezee! het jaarlijks Kopperfeest,
# Zal men deez’ avond vieren ;
# Wij zullen met verblijden geest,
# Het weer door eendragt sieren.
#
# VROUWEN.
# Vivat! hier op Apollo's grond,
# Genaakt de lang gewenschte stond;
# De vreugd van vroeger jaren
# Zal men op nieuw vergaren.
#
# TE ZAMEN.
# Lang leev’ den Typografen Kring!
# Zijn Stichters roem en eer!
# Op ’t doel, dat eenmaaf uit hun ging,
# Kwam Godes zegen neér.
#
# MANNEN,
# Fen dankbre groet aan u gebragt,
# Geachte rei PATRONEN!
# Uw bijstand schonk aan Voorzorg kracht,
# Gij ziet uw doel bekroonen.
#
# VROUWEN.
# Gewis de uitkomst is zoo schoon ,
# Want menig dankbren Costerzoon ,
# Mogt Voorzorgs hulp ervaren,
# In 't wegental van jaren,
#
# TER ZAMEN.
# Lang leev’ den Typografen Kring!
# Patronen! lof en eer;
# Op 't geen wat men van u ontving ,
# Kwam Godes zegen neer !
#
# MANNEN.
# Voor u ook galmt ons blijde lied ,
# Geachte DONATEUREN !
# Uw hulp gaf bij een bang verschiet ,
# Veraming aan die treuren.
#
# VROUWEN.
# Als ziekte in de woning treedt,
# Is onze zaak tot hulp gereed ;
# Uw bijstand schraagt dit pogen,
# Deed menig traan reeds droogen.
#
# TE ZAMEN.
# Lang leev’ den Typografen Kring!
# Heil , die hem bijstand biedt ;
# Want op de kracht, die men ontving,
# Ontbrak Gods zegen niet!
#
# MANNEN.
# Dat Hij, die in den Hemel leeft ,
# Dien zegen moog vermeeren !
# Als eens de werkkracht ons begeeft ,
# Moog Voorzorg armoed’ keeren ;
#
# VROUWEN.
# En zij het dan in later tijd ,
# Eens maakt de leus der weeuw verblijd ;
# Door vaderlooze weezen ,
# Zij nog haar nut geprezen ;
#
# TE ZAMEN.
# Lang leev’ den Typografen Kring !
# In Amstels maatschappij,
# Bloeit hij als eene eersteling ,
# Tot nut der Drukkerij!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1858
# songID                  amsterdam1849-feestliederen1858-04
# titel                                            Drinklied
# wijze                                             Io Vivat
# jaartal                                               1858
# schrijver                                   J.H.F. Bartels
# vereniging_schrijver                         amsterdam1849
# Name: 124, dtype: object
# -- song: --
# Drinklied
#
# Komt, Vriendenschaar !
# Het feest is daar,
# Schenkt nu de glazen in;
# Wij zingen luid met hart en mond ,
# Het voorregt van deez’ blijden stond,
# Komt, Vriendenschaar! enz.
#
# Wie stemt thans niet,
# In ’t vrolijk lied,
# Op ongedwongen toon;
# Fen achttal jaren ging voorbij,
# En, vrienden! daarom jublen wij;
# Wie stemt thans miet, eaz.
#
# Zoo voelt ons hart,
# Geen zorg of smart,
# O, Vrienden! in dit uur;
# Met zang en loutre vrolijkheid,
# Zij deze dag der vreugd gewijd ;
# Zoo voelt ons hart, enz.
#
# Komt, Vriendenschaar!
# Het feest is daar,
# Komt ledigt nu uw glas;
# Dat de avond vrolijk heen moog’ gaan,
# Bn menig feest nog moog’ bestaan,
# Komt, Vriendenschaar! enz.
#
# -- data: --
# typoID                                                   amsterdam1849
# sourceID                               amsterdam1849-feestliederen1858
# songID                              amsterdam1849-feestliederen1858-05
# titel                                  Een nieuw lied op een oude wijs
# wijze                   Hij zwaait met zijn hoedje het laatste vaarwel
# jaartal                                                           1858
# schrijver                                                   J. Breeman
# vereniging_schrijver                                     amsterdam1849
# Name: 125, dtype: object
# -- song: --
# Een nieuw lied op een oude wijs
#
# Nu nog eens een liedje op ’t jaarlijksche feest ,
# Wie is er op heden niet vrolijk van geest?
# Want immers de uren vervliegen zoo snel,
# En dan zwaait de hoed voor een jaar weer vaarwel,
#
# Al buldert de wind ook daar buiten zoo bang,
# Al viel ook de gang naar Apollo wat lang ,
# Vergeten is alles, de vreugde is groot,
# Wij zitten hier warmpjes in Abrahams schoot.
#
# Ons speeltuig is morgen de pers en de haak ,
# Zij rusten op heden, wij kennen geen’ taak ,
# Wij riepen deez’ ochtend , zoo blijvol, zoo wel
# Aan beiden tot morgen een vrolijk vaarwel !
#
# Nu drinken, nu zingen, nu dansen wij zaim,
# En brengen wij hulde aan Coster zijn’ naam,
# En zijn wij vermoeid, dan roept ieder Gezel,
# Op nieuw weér aan LOUWTJE een jaar lang vaarwel!
#
# Een zaak als de onze zoo zijn er niet veel!
# Een ieder ontvangt er zijn kinderlijk deel ;
# Bij ziekte, bij rampen, hoe kort of hoe fel,
# En ook als men roept aan het leven vaarwel!
#
# Zoo ging het reeds jaren, zoo moog’ het steeds gaan!
# Dan breekt er nog menige Kopperdag aan;
# En zijn wij eens oud en soms weinig in tel,
# Dan zwaait onze hoed voor het laatste vaarwel!
#
# -- data: --
# typoID                                                      amsterdam1849
# sourceID                                  amsterdam1849-feestliederen1858
# songID                                 amsterdam1849-feestliederen1858-13
# titel                   Aan de Typographische Zangvereeniging: Lourens...
# wijze                                         De wereld is in rep en roer
# jaartal                                                              1858
# schrijver                                                     J.J. Wakker
# vereniging_schrijver                                        amsterdam1849
# Name: 133, dtype: object
# -- song: --
# Aan de typographische zangvereeniging: Lournes Jansz Coster
#
# Komt, vrienden! schaart u in het rond,
# En zingt in deze blijde stond,
# Een lied, dat ons doet hooren,
# Hoe dat gij in een korten tijd,
# Een koorzang voor ons hebt bereid ,
# Laat niets uw aandacht storen.
#
# Den edlen Smits, wiens lust het is,
# Zal u weldra de toon uit Cis,
# Aangeven om te hooren,
# Dat gij niet in de plaats van Cis,
# Zult zingen A, B mol of Fis,
# Dat zou ons niet bekoren.
#
# Dus, Vrienden! let op uw partij,
# Zet andre zinnen op een zij,
# Dat strekt ter uwer eere;
# Wij zullen dan uw welkomstgroet ,
# Die gij voor ’t eerst ons hooren doet ,
# Vrolijk applaudiceeren.
#
# Gaat dan zoo voort met uwe zaak,
# Die ieder strekke tot vermaak,
# Daar kan iets goeds uit groeijen;
# Wij wenschen dan ook onderling,
# Dat deze uw Vereeniging,
# Steeds meer en meer moog bloeijen!
# -- data: --
# typoID                                            amsterdam1849
# sourceID                        amsterdam1849-feestliederen1859
# songID                       amsterdam1849-feestliederen1859-08
# titel                                      Een verstandige raad
# wijze                   Wie praalt aan 't hoofd der Heldenstoet
# jaartal                                                    1859
# schrijver                                       R. van der Star
# vereniging_schrijver                              amsterdam1849
# Name: 141, dtype: object
# -- song: --
# Een verstandige raad
#
# Op nieuw viert men het Kopperfeest, Hoezee!
# Elk onzer is verheugd van geest, Hoezee!
# Bij goede Punsch en lekkre Wijn,
# Kan men zoo taam’lijk vrolijk zijn,
# Hoezee! Hoezee! Hoezee!
#
# Apollo is wel ver van huis, tis waar!
# Het is een eind naar Amstels sluis, ’t is waar!
# Hoe menig moest net aangedaan,
# In weêr en wind naar ’t feest toe gaan,
# t Is waar, 't is waar 't is waar!
#
# Maar zijn we er eenmaal aangeland, gewis!
# Dan zetten wij die marsh aan kant, gewis!
# Men denkt aan niets dan aan de vreugd,
# En aan de dag die ons verheugd,
# Gewis! gewis! gewis!
#
# Maar nogmaals dient die togt gedaan, o wee!
# En schoon wij dan iets losser staan, o wee!
# Hoe afgemat, hoe zwak, hoe moê
# Toch moet men naar zijn woning toe
# o Wee! o wee! o wee!
#
# Dus vrienden! volgen wij den raad, o ja!
# Een wijs man gaf die inderdaad, o ja!
# Hij sprak: Wilt altijd vrolijk zijn,
# Maar drinkt vooral geen Punsch of Wijn
# ja! ja! ja! ja! ja!
#
# Och zulk een raad is ook al mis, niet waar?
# Gij allen denk dit naar ik gis, iet waar?
# Lat dus die wijze matig zijn,
# Wij drinken heden Punsch en Wijn,
# Dat 's klaar! dat 's klaar! dat 's klaar!
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1859
# songID                  amsterdam1849-feestliederen1859-09
# titel                                           Hulde lied
# wijze                          De wereld is in rep en roer
# jaartal                                               1859
# schrijver                                       J. Clausen
# vereniging_schrijver                         amsterdam1849
# Name: 142, dtype: object
# -- song: --
# Hulde-lied
#
# Zie zoo, deez’ feestdag is weêr daar,
# En ziet, wij zijn van zessen klaar ,
# Om vrolijk feest te vieren,
# Wie is er. nu niet blij van geest,
# Op 't vrolijk Koppermaandagfeest ?
# Wie moet het meest het sieren?
#
# Is t niet vriend BREEMAN, die altijd,
# Zijn zorg heeft aan de zaak gewijd,
# Ons menig uur wou geven;
# Hij ijvert steeds voor deze Kring,
# Voor ons, zijn vrienden, onderling,
# Dit is zijn eenigst-streven
#
# Daarom zij hem dan in dit uur,
# Bezielt met ’t reinste vriendschapsvuur ,
# Een danklied aangeheven; (bés)
# Hij toch is ’t hoofd van dit ons feest,
# Wij wenschen hem dan blij van geest.
# Lang voor deez’ Kring te leven
#
# Dat ieder Kopperfeestgetij,
# Ook door zijn werk vervrolijkt zij,
# Waar meu mag roem op dragen;
# Zoo komen wij steeds jaar op jaar,
# Is deze feestdag dan weêr daar,
# Op nieuw wat van hem vragen
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1861
# songID                  amsterdam1849-feestliederen1861-01
# titel                      Een verhaal op waarheid gegrond
# wijze                          De wereld is in rep en roer
# jaartal                                               1861
# schrijver                                         H. Stühr
# vereniging_schrijver                         amsterdam1849
# Name: 147, dtype: object
# -- song: --
# Een verhaal, op waarheid gegrond
#
# Een knaap ('t was achttienhonderd vijf),
# Die drukkunst koos tot zijn bedrijf,
# Als man haar nog hanteerde ,
# Getuigt, dat toen het Kopperfeest
# Geschoeid was op een andre leest,
# Dan nu men haar vereerde.
#
# Dien dag dronk men zich meestal zat
# Van ’t alverdoovend Bacchusnat ,
# Zoo lang de schijven duurden;
# Maar zag oom Pluto barsch hen aan,
# Dan schoof men waglend langs de baan,
# Tot men zijn stulp begluurde.
#
# Kwam dan de Typograaph te huis,
# Dan was er soms geen munt, noch kruis,
# Bij greep meer te vinden ;
# Voor moeder, die het klene kroost
# Met vaders thuiskomst had getroost ,
# Was het en bleef een blinde.
#
# Maar thans viert deez’ Vereeniging
# Het Kopperfeest weêr onderling ,
# Door Voorzorg, met Genoegen;
# Paar 't Edel Achtbaar Hoofd der stad,
# Door een Wel-Edele rei omvat ,
# Zich gunstrijk tot ons voegen.
#
# Ja dank, Wel-Edele Heerenrei !
# Die met uw gunst ons blijft nabij,
# Moog lang die gunst ons kroonen ;
# Dan zullen wij met blijden geest, fn
# Nog menig jaarlijks Kopperfeest ,
# U onzen dank betoonen.
#
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1861
# songID                  amsterdam1849-feestliederen1861-02
# titel                                De roem der drukkunst
# wijze                                             Io Vivat
# jaartal                                               1861
# schrijver                                     J.F. Vissers
# vereniging_schrijver                         amsterdam1849
# Name: 148, dtype: object
# -- song: --
# De roem der drukkunst
#
# Wij roemen u, wij roemen u,
# O Drukkunst! ons zoo waard ;
# Daar wij thans op het Kopperfeest,
# Vereenigd zijn met hart en geest;
# Wij noemen u, wij noemen u,
# De grootste schat op aard’.
#
# U, schoone kunst! u, schoone kunst!
# Looft steeds ons hart en mond;
# Haar rijk vernuft kent maat, noch peil,
# Schenkt ons de grootste bron van heil;
# Gij blijft de kunst! gij blijft de kunst!
# Van Bato's dierbren grond.
#
# Wordt ook die eer, wordt ook die eer,
# Miskent van allen kant,
# Van hier, die ons die kroon ontrooft,
# Aan Guttenberg den krans belooft ;
# Wij juichen blij, en roemen vrij,
# Die schat hoort Nederland.
#
# Europa noemt, Europa noemt,
# De druk een’ rijken vond;
# Ja, volksgeluk en wetenschap ,
# Brengt zij op eenen hoogen trap;
# Oud-Neérland roemt, Oud-Neérland roemt,
# Deez’ vinding van haar’ grond.
#
# Zij brengt haar heil! zij brengt haar heil!
# Tot aan het verste strand ;
# De godsdienst, bron van rust en kracht,
# Wordt door u hulp alom gebragt ;
# Blijf, Boekdrukkunst! blijf met dit heil!
# Ook in ons vaderland.
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1861
# songID                  amsterdam1849-feestliederen1861-05
# titel                                                Varia
# wijze                                           [diversen]
# jaartal                                               1861
# schrijver                                              NaN
# vereniging_schrijver                         amsterdam1849
# Name: 151, dtype: object
# -- song: --
# Varia
#
# TE ZAMEN:
# Verheffen wij met kracht en klem ,
# Op 't Kopperfeest ons aller stem,
# Om onze vreugd te toonen ;
#
# VROUWEN:
# Het beste kleed is aangedaan ,
# En vrolijk zijn wij opgegaan ,
# Om 't jaarfeest bij te wonen.
#
# MANNEN:
# Weder is een jaar vervlogen ,
# Hooger magt was ons nabij,
# Gaf zijn zegen op ons pogen ,
#
# TE ZAMEN:
# Vrij en blij,
# Tellen wij,
#
# VROUWEN:
# Thans een twaalftal schoone jaren,
# Waarin ieder kon ontwaren,
# Dat , waar eensgezindheid woont ,
# Ware hulp het pogen kroont.
#
# MANNEN:
# Hoezee! de vreugde rijst ten top,
# Haalt, Broeders! nog eens vrolijk op,
# En laat het lied weêrgalmen door deez’ zaal;
# Wie onzer is niet blij van geest,
# Wie juicht niet op ons Kopperfeest ,
# Al is 't in zwakke taal,
#
# TE ZAMEN:
# Triomf! de blijde dag is daar, hoezee!
# Dat wij vereenigd met elkaâr, hoezee!
# Bij zang en dans, bij punsch en wijn,
# Als Costerzonen vrolijk zijn ,
# Hoezee! hoezee! hoezee!
#
# VROUWEN:
# Ook wij, wij deelen in die vreugd, 't ís waar,
# Geen dag, die meerder ons verhengt, in 't jaar,
# En schoon de zorg ons veeltijds kwelt ,
# Op heden wordt zij niet geteld,
# 't Is waar, zoo eens im ’t jaar.
#
# MANNEN:
# Zegt, Vrienden! weet gij van 't geval,
# Dat onlangs is besloten,
# Wis, dat een elk hem roemen nel,
# Uit wie dit is gesproten.
# Vertelt het wijd en zijd,
# Want is 't weër zomertijd ,
# Een achtste Eeuw van ons bestaan,
# Dan zal de dank hen sieren „
# Door wien t ons goed mogt gran.
#
# DE VROUWEN, AAN HET WERKEND PERSONEEL:
# Spant u dan in,
# Spant u dan in,
# Op dit zoo heuglijk feest ;
# Zorgt, dat door oefening en vlijt,
# Gij van dat feest het sieraad zijt.
# Spant u dan in,
# Schenkt niet te min,
# De vruchten van uw' geest.
#
# -- data: --
# typoID                                            amsterdam1849
# sourceID                        amsterdam1849-feestliederen1861
# songID                       amsterdam1849-feestliederen1861-09
# titel                                          De koppermaandag
# wijze                   Wie praalt aan 't hoofd der Heldenstoet
# jaartal                                                    1861
# schrijver                                         J.M. van Gool
# vereniging_schrijver                              amsterdam1849
# Name: 156, dtype: object
# -- song: --
# De koppermaandag
#
# Al luidt geen klok, al waait geen vlag, hoezee
# ts toch een feestelijke dag, hoezee !
# Een dag van wezentlijke vreugd ,
# Sinds twaalf jaar ìn eer en deugd,
# Hoezee! hoeze! hoezee !
#
# En of er goede grond voor is, o ja!
# Dat het door Costers vinding is, o ja!
# Dat wij hier bij elkander zijn,
# Verheugd en blij bij een glas wijn.
# O ja, O ja, O ja.
#
# Dit feest is voor ons allen schoon, gewis!
# Weldra vereerd met de eerekroon, gewis!
# Al is zij dan van koper maar,
# Van zilver komt zij ook voorwaar.
# Voorwaar , voorwaar , voorwaar.
#
# Het is toch eene schoone taak, ’t is goed!
# De broederhand te schenken vaak, met moed!
# Dat is de taak van onzen Kring,
# Van ieder lid en feesteling.
# Met een opregt gemoed,
#
# Hoezee! vivat! zoo klinke, ons lied, hoezee !
# De vreugd, die deze dag ons biedt, hoezee !
# Genieten wij zoo als t behoort,
# Geen twist of tweedragt, die ze stoort,
# Hoezee! hoezee! hoezee!
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1861
# songID                  amsterdam1849-feestliederen1861-11
# titel                                         Arme vrouwen
# wijze                             Eine kleine wunderschone
# jaartal                                               1861
# schrijver                                       J. Breeman
# vereniging_schrijver                         amsterdam1849
# Name: 158, dtype: object
# -- song: --
# Arme vrouwen
#
# MANNEN:
# Feestgenooten! laat ons zingen, want de tijd gaat spoedig voort,
# 't Is bij ons toch maar een puikje, nooit wordt er de rust verstoord;
# Vrolijk komt men, vrolijk blijft men, vrolijk gaat men weêr naar huis,
# Weg met twist en ruziemaken, bij het lieflijk feestgedruisch!
# Druisch, druisch, druisch, enz.
#
# VROUWEN:
# Is zeer schoon, dat gij moogt roemen, jaarlijks op uw feestpartij;
# Maar kent gij een kring van vrouwen, vredelievender dan wij?
# 't Is vrij zot, dat gij die wijsheid dus aan u alleen toekent,
# Schoon, dat zijn wij, arme vrouwen! van de mannen wel gewend,
# Wend, wend, wend, enz.
#
# MANNEN:
# Nooit mag men een woordje spreken, of gereed tot hekelzucht,
# Valt gij met uw Jermiade aard’ en hemel, ja de lucht
# Moet weêrgalmen van uw klagten, en gij raast, gij scheldt, gij tiert,
# Noemt u daarbij arme Vrouwen! arm, als men een feesttij viert?
# Viert, viert, viert, enz.
#
# VROUWEN:
# Excuseert ons, deze uitroep was wel niet zoo kwaad gemeend,
# Wij zijn beden veel te vrolijk, nu dit feest ons weêr vereent;
# Doch wij nemen geene jota van 't gesprokene terug,
# In het eigen lofbazuinen zijt gij, mannen! altijd vlug.
# Vlug, vlug, vlug, enz,
#
# MANNEN:
# Feestgenooten! wilt maar zwijgen, eer het ons genot verstoort,
# 't Is u allen vaak gebleken, vrouwlief heeft het laatste woord.
#
# VROUWEN:
# Nooit zal men het u vergeven, dat ge ons op dit feest bespot,
# Vrouwen! Vrouwen! arme Vrouwen! hoe beklaaglijk is ons lot.
# Lot, lot, lot, enz.
#
# -- data: --
# typoID                                       amsterdam1849
# sourceID                   amsterdam1849-feestliederen1862
# songID                  amsterdam1849-feestliederen1862-01
# titel                                        Welkomstgroet
# wijze                        Van alle landen op deez’ aard
# jaartal                                               1862
# schrijver                                       J. Buhling
# vereniging_schrijver                         amsterdam1849
# Name: 159, dtype: object
# -- song: --
# Welkomstgroet
#
# ...
# Ja, ieders smarten zijn gelenigd,
# Wanneer men ’t oog slechts rigt op hem,
# Die door zijn brein in éénen stond
# Verlichtte heel het wereldrond,
#
# Wis, Kosters Kunst gaf licht en leven
# Tot hooge weldaad aan dees aard ,
# Het duister werd dooy hem verdreven ,
# En daarom is hij ’t loflied waard:
# Dat dus zijn roem en nutte dadn
# Ons in de Kunst staag voort doen gaan!
#
# Mannen-Koor.
# O, laat ons steeds, bij ’t ijvrig zwoegen
# Ons aller doel gedachtig zijn:
# Het schenkt ons Nut en Vergenoegen.
# Dat oogmerk blijf ons allen rein.
# Dat streven lach ons allen toe ,
# Nooit worden wij het helpen moe!
#
# Vrouwen-Koor.
# O, blijft dan, mannen! steeds indachtig
# De wenschen, in dees zang geuit:
# Blijf uw Verbond steeds sterk en krachtig,
# Gelijk een boom, met spruit bij spruit;
# Want uw geluk is ons geluk,
# En blijf door Druk elk vrij van druk.
# -- data: --
# typoID                                     utrecht1851
# sourceID                   utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-01
# titel                                    Welkomstgroet
# wijze                                    Ons vaderland
# jaartal                                           1868
# schrijver                                 J. Haasbroek
# vereniging_schrijver                       utrecht1851
# Name: 704, dtype: object
# -- song: --
# Welkomst-groet
#
# Zijt allen welkom op dit Feest,
# Geachte Deelgenooten ;
# Wil met een opgeruimden geest,
# Ons aller vreugd vergrooten;
#
#
# Ik wensch u heden veel pleizier,
# Met liev’ling of uw vrouwtje
# Zoekt dezen avond uw vertier ,
# Wees niet te veel aan ’t touwtje;
# Het is toch van geen langen duur ,
# De klok slaat aanstonds weer vier uur,
# En dan is ’t voor ons lang geen smoutje:
#
# De Harmonie in onzen kring,
# Dat het nog jaren dure,
# En ook "t genoegen onderling.
# 't Zal hopen w' nooit verguren,
# 't Genoegen en de Harmonie
# Gaan zaam, en dan de vraag toch wie
# Zal deze vreugde niet herdenken.
# -- data: --
# typoID                                        utrecht1851
# sourceID                      utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-02_03
# titel                                                 NaN
# wijze                                      De Koning leef
# jaartal                                              1868
# schrijver                                      B. Lageman
# vereniging_schrijver                          utrecht1851
# Name: 706, dtype: object
# -- song: --
# 3
# De Drukkunst leev’! de Drukkunst leev’!
# En moog’ steeds meerder bloeijen,
# Dat zij ons immer arbeid geev’,
# Elks welvaart steeds doe groeijen
# Dan vinden wij ons ieder jaar,
# In blij genoegen bij elkaar
#
# Wij viechten haar een eerlauwrier,
# En juichen haar ter eere, ,
# Dat voor een uitgebreid vertier
# Haar luister steeds vermeere ;
# Zoo klinke ’t rond van strand tot strand ,
# De Drukkunst leev’ in Nederland.
#
# -- data: --
# typoID                                        utrecht1851
# sourceID                      utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-02_04
# titel                                                 NaN
# wijze                                         Rambambolie
# jaartal                                              1868
# schrijver                                      B. Lageman
# vereniging_schrijver                          utrecht1851
# Name: 707, dtype: object
# -- song: --
# 4
# Komt daarop ’t glas omhoog geheven,
# En bij een ongedwongen stem,
# Ook door een feestdronk blijk gegeven.
# Dat ieders oog steeds staar’ op Hem
# Die door zijn nooit volprezen vond
# Verlichtte heel het wereldrond.
#
# O! laat ook steeds voor wat wy zwoegen ,
# Ons ’t heilrijk doel deelachtig zjn,
# Dat toch, schenkt Nut en ook Genoegen,
# Dat oogmerk zij ons allen rein,
# Komt wijden wij dan onderling ,
# Een dronk aan dezen Vriendenkring,
#
# O blijft toch mannen steeds indachtig,
# De Vriendentoon door U geuit,
# Dan blijv’ deez’ Kring vaak sterk en krachtig,
# En ga in welvaart steeds vooruit; —
# Die welvaart die Uw zaam verheugd,
# Zij ons ook dan ten ware vreugd.
# -- data: --
# typoID                                        utrecht1851
# sourceID                      utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-02_07
# titel                                                 NaN
# wijze                                Wien Neerlands bloed
# jaartal                                              1868
# schrijver                                      B. Lageman
# vereniging_schrijver                          utrecht1851
# Name: 710, dtype: object
# -- song: --
# 7
# Wie zou nu met dien goeden geest
# Niet hart'lijk zijn verblijd,
# Op ’t zoo genoeg'lijk Kopperfeest,
# Der Drukkunst toegewijd ;
#
# Verban dan alle zorg van hier,
# Leev’ lang door Costers gunst,
# Als Broeders onder één banier ;
# Leev’ Costers ed‘le kunst!
# -- data: --
# typoID                                        utrecht1851
# sourceID                      utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-02_08
# titel                                                 NaN
# wijze                                   De scharenslijper
# jaartal                                              1868
# schrijver                                      B. Lageman
# vereniging_schrijver                          utrecht1851
# Name: 711, dtype: object
# -- song: --
# 8
# Komt waarde Feestgenooten,
# Door vriendschap thans vergaard,
# Met vreugd U aangesloten,
# En tot een marsch geschaard;
# Komt schaart U, komt schaart U!
# Thans vrolijk paar aan paar, — ja! ja.
#
# Wilt vrouwen ons vereeren,
# En sluit U bij ons aan,
# Schaart U bij ’t opmarcheeren,
# Vrij onder onze Vaan!
# Komt schaart U, komt schaart U!
# Vrij onder onze Vaan! — ja! ja
#
# Laat ons een wand’ling maken,
# Niets dat ons thans verstoort,
# Niets dat deez’ tocht doet staken,
# Wij wand'len vrolijk voort. :
# Wij wand’len, wij wand'len ,
# Al zingend, vroljk voort, — ja! ja-
#
# 't Zij krijgs- of oproertoonen,
# Bij andren soms gezocht,
# Als vrije Costerszonen
# Volbrengen wij deez’ tocht!
# Welaan Costerzonen !
# Volbrengen wij deez’ tocht, — ja! ja.
#
# -- data: --
# typoID                                        utrecht1851
# sourceID                      utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-02_09
# titel                                                 NaN
# wijze                        Mijn zuster heeft een vrijer
# jaartal                                              1868
# schrijver                                      B. Lageman
# vereniging_schrijver                          utrecht1851
# Name: 712, dtype: object
# -- song: --
# 9
# Vooruit dan Feestelingen, :
# Niet dansen en niet springen,
# Maar als een knap soldaat ,
# Marcheeren in de maat.
# Vooruit! vooruit zoo klink’ de toon
# Van elk Costerzoon! ja! ja!
#
# Wij gaan als Typografen,
# Geen Ieren of geen Zouafen,
# Versperren ons de baan’,
# Neen wij kunnen voorwaarts gaan.
# Vooruit! vooruit! enz.
#
# Het doet ons veel genoegen,
# Ons met U zaam te voegen
# En stappen vrij en bij,
# Als Gides aan Uw’ zij.
# Vooruit! vooruit! enz,
#
# Geen bergen of geen dalen,
# Geen scherpe zonnestralen ,
# Geen sneeuwval of orkaan ,
# Storen ons in ’t voorwaarts gaan.
# Vooruit! vooruit! enz.
#
# Niets kan ons dus verhind’ren,
# Wij gaan als Costers kind’ren ,
# En wand’len met pleizier ,
# Voorwaarts onder één banier,
# Vooruit! vooruit! enz,
#
# Mogt ons soms onspoed treffen,
# Wij ’t hoofd dan opwaarts heffen,
# En brengen nimmer moe
# Elkaar steeds hulpe toe!
# Vooruit! vooruit! enz.
#
# Het doel wat wij bevogen,
# Is ’t Nut steeds te verhoogen ,
# En wat ook sta of val,
# Dit blijve bij ons pal.
# Vooruit! vooruit! enz.
#
# En wat wij daarbij voegen,
# Is ’t zoo gewenscht Genoegen
# Waarin thans elk om strijd,
# Zich heden zoo verblijd!
# Lang bloeije de Vereeniging!
# In ruime zegening! o ja!
#
# -- data: --
# typoID                                     utrecht1851
# sourceID                   utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-03
# titel                                       Kopperlied
# wijze                                   't is u bekend
# jaartal                                           1868
# schrijver                                 Z. Haasbroek
# vereniging_schrijver                       utrecht1851
# Name: 713, dtype: object
# -- song: --
# Kopperlied
#
# Triomf! het Kopperfeest, is aangebroken,
# Dat ieder jaar zoo feestlijk wordt gevierd,
# De lust en eendracht wordt daar niet verbroken,
# Maar Laurens Costers-feest wordt daar versierd.
#
# Komt laat ons dan door vreugde opgetogen ,
# Op ’t blijde Coster-feest eens vrolijk zijn,
# Want morgen staat ons hoofd weer neergebogen,
# Komt drinken wij daarop een glaasje wijn.
#
# Juicht Vriendenschaar! de stem nu aangeheven,
# Want Vader Costers kunst vergaat toch niet,
# De glorie van dit alles is ons streven,
# Zij is het, die ons thans deez' vreugde biedt.
#
# Dit feestvermaak wordt nimmer toch vergeten;
# Niet één van ons, die zulk een wee veracht ;
# De lieve meisjes willen took wel weten,
# Dat zoo iets niet door hen is uitgedacht.
# -- data: --
# typoID                                     utrecht1851
# sourceID                   utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-04
# titel                               Zou het waar zijn?
# wijze                      De wereld is in rep en roer
# jaartal                                           1868
# schrijver                                   C. Mommaas
# vereniging_schrijver                       utrecht1851
# Name: 714, dtype: object
# -- song: --
# Zou het waar zijn?
#
# Zou “t waar zijn, dat een Typograaf
# Alleen den an heeft van heel braaf
# Ben jaar te kunnen sparen?
# Om, als het Januari is,
# Voor Coster mijn gedachtenis
# In feestdosch zich te scharen?
#
# Wel wis en zeker is het waar!
# Beschouwt maar eens deez’ Vriendenschaar ,
# Hoe aardig zij verkeeren
# Met hunne liefjes aan hun zij’,
# Op 't eenmaal jaarlijks feestgetij' ,
# 't Bespaarde geld verteeren ?
#
# Zou 't waar zijn, dat in heel ons land
# Men nergens vindt zoo’n broederband,
# Als juist bij Coster’s-zoonen ?
# Zou 't waar zijn, dat in geenen kring
# Men zoo veel hulp vindt onderling,
# Als zij elkaar betoonen ?
#
# Ja, wis en weker is het waar!
# Men helpt gulhartig steeds elkaar
# In nood en ramp en lijden !
# Maar, is de Koppermaandag daar,
# Dan weet zich dien Vriendenschaar
# Recht hartlijk te verblijden !
#
# Welnu, als dat dan waar mag zijn, .
# Klinkt dan, en drinkt een goed glas wijn,
# En zingt op hooge toonen :
# »Lang leev' in Utrecht dezen kring,
# »Die lief en leed draagt onderling !
# »Leev’ Utrechts Coster’s-zoonen !”
#
#
#
# -- data: --
# typoID                                     utrecht1851
# sourceID                   utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-05
# titel                   Door de kunst, nut en genoegen
# wijze                        Schep vreugde in 't leven
# jaartal                                           1868
# schrijver                                   J. Weelink
# vereniging_schrijver                       utrecht1851
# Name: 715, dtype: object
# -- song: --
# Door de kunst, nut en genoegen
#
# Heft Koster’s-vrienden !
# Luid het lied der Kunst thans aan;
# Stemt allen mede,
# 't Moet vrolijk gaan.
# 't Gebouw dier Kunst staat vast en wis,
# Omdat deez’ Kunst onz’ grondzuil is,
# Die, — wat ook wiss’len mag of keer,
# Kan mind’ren noch verkoelen.
# Heft Kosters vrienden, enz.
#
# Die Kunst geeft U een rein genot,
# Zij steeds uw troost in ’t levenslot.
# Verbind’ U daaraan hecht en teer,
# En zij uw schild en hope.
# Heft Kosters vrienden, enz.
#
# En zie maar in deez’ Zaal eens rond,
# Die blijde lach om elken mond,
# Dat is de bode die U meldt:
# »De liefde voor die Kunsten.”
# Heft Kosters vrienden, enz.
#
# En neem van 't Feest deez' bede mee:
# Dat er steeds voorspoed heersche en vree,
# Die Kunst, ja! door verstand em geest.
# Mag voortgaan in GENOEGEN.
# Heft Kosters vrienden, enz.
#
# En waar die Kunst genoegen vindt,
# Daar wordt zij nog veel meer bemint
# Voor 't NUT, dat zij aan ons nog geeft
# In ramp of tegenspoeden.
# Heft Kosters vrienden, enz.
#
# Een vreugdetoon daarom aan Hem
# Die ze uitvond; ja, met gulle stem
# En met een opgeruimd gemoed :
# Lang leve Kosters vinding !”
# Heft Kosters vrienden, enz.
#
# -- data: --
# typoID                                     utrecht1851
# sourceID                   utrecht1851-feestzangen1868
# songID                  utrecht1851-feestzangen1868-08
# titel                                    Afscheidslied
# wijze                      De wereld is in rep en roer
# jaartal                                           1868
# schrijver                                   B. Lageman
# vereniging_schrijver                       utrecht1851
# Name: 718, dtype: object
# -- song: --
# Afscheidslied
#
# Het spreekwoord overoud bekend :
# »Aan alle zaken komt een end!”
# Kan men nu niet bestrijden,
# Want weer vervlogen is de tijd,
# En ’t klokje van gehoorzaamheid,
# Dat waarschuwt ons te scheiden.
#
# Maar voor wij van elkander gaan,
# Vat elk nog eens zijn glaasje aan,
# En wijde wel te vreden,
# Een dronk, aan den vervlogen nacht,
# Zoo regt genoeglijk doorgebragt,
# Op 't Kopperfeest van heden.
#
# Hoe vrolijk waren wij bijeen,
# ‘t Was jublen, dansen om ons heen,
# Waar wij ons in verlusten;
# Thans wenschen wij als wél voldaan,
# Voor dat wij uit elkander gaan,
# Een ieder: wel te rusten!
#
# Dat dezen kring, dit wenschen wij,
# Tot sieraad van de maatschappij,
# Nog lang haar NUT mag toonen;
# Dat vriendschap en verbroedering ,
# Haar hulp betoone onderling ,
# En woon’ bij Costerszonen.
#
# Triomf! daarop het glas omhoog,
# Voldoening straal’ uit ieders oog,
# En wat wij zamen voegen:
# Is bij de wenschen ,,Goeden nacht”
# Te juichen, met vereende kracht:
# Lang leev’ ,NUT en GENOEGEN !”
#
# -- data: --
# typoID                                     utrecht1851
# sourceID                   utrecht1851-feestzangen1869
# songID                  utrecht1851-feestzangen1869-03
# titel                                        Feestlied
# wijze                                   De Koning leef
# jaartal                                           1869
# schrijver                                  F.C. Picard
# vereniging_schrijver                       utrecht1851
# Name: 721, dtype: object
# -- song: --
# Feestlied
#
# De juichtoon klink! de dag herrees
# Van Costers edle vinding ,
# De vinding , die haar heil bewees
# Door menschen-geest-ontbinding ,
# Die Kunst, van boven afgedaald,
# Heeft ’t eerst ons met haar glans bestraald.
#
# Roem, Haarlem! roem op de eerekroon ,
# Die Duitschland U wo rooven;
# Het regt besliste uw regt, zoo schoon,
# Niets kan uw luister dooven.
# O stad van ’t Spaarne, stad van ’t licht!
# Het duister heeft voor U gezwicht.
#
# Blijft , Nederlanders! onverlet ,
# Door drukkunst deugden kweeken ,
# En 't heilig vuur voor Orde en Wet
# In uw gemoed ontsteken!
# Leg men haar smaadvol ginds aan band,
# Hier is ze vrij, m Nederland!
#
# Zoo zien wij nooit op onzen grond
# De drukkunst kwaad verspreiden ;
# Zij zal, jaar in, jaar uit, in “trond,
# Haar nut, hier 't doel , bereiden :
# Hier, waar ze op Costers wenk ontstond ,
# Hier is ze vrij, op Neerlands grond !
#
# -- data: --
# typoID                                     utrecht1851
# sourceID                   utrecht1851-feestzangen1869
# songID                  utrecht1851-feestzangen1869-05
# titel                                        Feestlied
# wijze                        O groote koopman in tabak
# jaartal                                           1869
# schrijver                                 Z. Haasbroek
# vereniging_schrijver                       utrecht1851
# Name: 723, dtype: object
# -- song: --
# Feestlied
#
# Het Kopperfeest is nu reeds daar,
# Dat eens gevierd wordt in het jaar
# Een ieder met zijn vrouwtje;
# De zorg nu aan een kant gezet ,
# Want anders hebben wij geen pret,
# Dat is voor ons een smoutje.
#
# Zoo gaat men voort van mond tot mond,
# En loopt de heele wereld rond
# Geen pret zoo groot als deze;
# En dus vooruit en anders niet ,
# Het is hetgeen wat Coster biedt,
# Het moet niet anders wezen.
#
# Komaan het glas omhoog gevat ,
# En maakt de lippen nu eens nat,
# Dan wordt de pret veel grooter;
# Want zingen, drinken hoort er bij,
# De Typograaf die is nu vrij,
# En zit nu in geen klooster.
#
# En nu de vrouwtjes eens gepakt ,
# Zij zien nu op geen stuk of wat,
# Zij zijn nu niet verlegen;
# En val kom, het is nu feest,
# Het valt ons nu zoo in den geest,
# Daar heb ik niets op tegen.
